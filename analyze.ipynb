# %%
import jsonlines
import matplotlib.pyplot as plt

#{"mode": "train", "epoch": 1, "iter": 1050, "lr": 5e-05, "memory": 8994, "data_time": 0.00407, "loss_rpn_cls0_w0.5": 0.00742, "loss_rpn_bbox0_w0.5": 0.0035, "loss_rpn_cls1": 0.01133, "loss_rpn_bbox1": 0.00609, "s0.loss_cls0_w0.5": 0.08677, "s0.acc0": 47.03711, "s0.loss_bbox0_w0.5": 0.07776, "s1.loss_cls0_w0.5": 0.0236, "s1.acc0": 48.54883, "s1.loss_bbox0_w0.5": 0.01544, "s2.loss_cls0_w0.5": 0.0048, "s2.acc0": 49.41016, "s2.loss_bbox0_w0.5": 0.00222, "s0.loss_cls1": 0.16868, "s0.acc1": 94.04297, "s0.loss_bbox1": 0.14835, "s1.loss_cls1": 0.0447, "s1.acc1": 97.23828, "s1.loss_bbox1": 0.02953, "s2.loss_cls1": 0.00893, "s2.acc1": 98.86328, "s2.loss_bbox1": 0.00439, "loss": 0.64351, "time": 0.72019}
#{"mode": "val", "epoch": 1, "iter": 106, "lr": 5e-05, "AP50": 0.913, "mAP": 0.91305}
i=1
it=0
iter=[]
lr=[]
loss=[]
AP50=[]
mAP=[]
s0_acc0=[]
s1_acc0=[]
s2_acc0=[]
s0_acc1=[]
s1_acc1=[]
s2_acc1=[]
epoch=[]
with open("work_dirs/train_val09_50/50epoch.log.json", "r+", encoding="utf8") as f:
    for item in jsonlines.Reader(f):
        if "mode" in item.keys():
            if item['mode'] == 'train':
                lr.append(item['lr'])
                loss.append(item['loss'])
                s0_acc0.append(item['s0.acc0'])
                s1_acc0.append(item['s1.acc0'])
                s2_acc0.append(item['s2.acc0'])
                s0_acc1.append(item['s0.acc1'])
                s1_acc1.append(item['s1.acc1'])
                s2_acc1.append(item['s2.acc1'])
                iter.append(it)
                it+=50
            
            if item['mode'] == 'val':
                if "AP50" in item.keys():
                    AP50.append(item['AP50'])
                    mAP.append(item['mAP'])
                    epoch.append(i)
                    i+=1

#train
plt.plot(iter, lr)
plt.title("learing rate")
plt.show()

plt.plot(iter,s0_acc0)
plt.title("s0_acc0")
plt.show()

plt.plot(iter,s1_acc0)
plt.title("s1_acc0")
plt.show()

plt.plot(iter,s0_acc0)
plt.title("s2_acc0")
plt.show()

plt.plot(iter,s1_acc0)
plt.title("s0_acc1")
plt.show()

plt.plot(iter,s0_acc0)
plt.title("s1_acc1")
plt.show()

plt.plot(iter,s1_acc0)
plt.title("s2_acc1")
plt.show()


#val

plt.plot(epoch, AP50)
plt.title("VAL AP50")
plt.show()

plt.plot(epoch,mAP)
plt.title("mAP")
plt.show()

# %%
import jsonlines
import matplotlib.pyplot as plt

#{"mode": "train", "epoch": 1, "iter": 1050, "lr": 5e-05, "memory": 8994, "data_time": 0.00407, "loss_rpn_cls0_w0.5": 0.00742, "loss_rpn_bbox0_w0.5": 0.0035, "loss_rpn_cls1": 0.01133, "loss_rpn_bbox1": 0.00609, "s0.loss_cls0_w0.5": 0.08677, "s0.acc0": 47.03711, "s0.loss_bbox0_w0.5": 0.07776, "s1.loss_cls0_w0.5": 0.0236, "s1.acc0": 48.54883, "s1.loss_bbox0_w0.5": 0.01544, "s2.loss_cls0_w0.5": 0.0048, "s2.acc0": 49.41016, "s2.loss_bbox0_w0.5": 0.00222, "s0.loss_cls1": 0.16868, "s0.acc1": 94.04297, "s0.loss_bbox1": 0.14835, "s1.loss_cls1": 0.0447, "s1.acc1": 97.23828, "s1.loss_bbox1": 0.02953, "s2.loss_cls1": 0.00893, "s2.acc1": 98.86328, "s2.loss_bbox1": 0.00439, "loss": 0.64351, "time": 0.72019}
#{"mode": "val", "epoch": 1, "iter": 106, "lr": 5e-05, "AP50": 0.913, "mAP": 0.91305}
i=1
it=0
iter=[]
lr=[]
loss=[]
AP50=[]
mAP=[]
s0_acc0=[]
s1_acc0=[]
s2_acc0=[]
s0_acc1=[]
s1_acc1=[]
s2_acc1=[]
epoch=[]
with open("work_dirs/new_epoch7/20220531_093708.log.json", "r+", encoding="utf8") as f:
    for item in jsonlines.Reader(f):
        if "mode" in item.keys():
            if item['mode'] == 'train':
                lr.append(item['lr'])
                loss.append(item['loss'])
                s0_acc0.append(item['s0.acc0'])
                s1_acc0.append(item['s1.acc0'])
                s2_acc0.append(item['s2.acc0'])
                s0_acc1.append(item['s0.acc1'])
                s1_acc1.append(item['s1.acc1'])
                s2_acc1.append(item['s2.acc1'])
                iter.append(it)
                it+=50
            
            if item['mode'] == 'val':
                if "AP50" in item.keys():
                    AP50.append(item['AP50'])
                    mAP.append(item['mAP'])
                    epoch.append(i)
                    i+=1

#train
plt.plot(iter, lr)
plt.title("learing rate")
plt.show()

plt.plot(iter,s0_acc0)
plt.title("s0_acc0")
plt.show()

plt.plot(iter,s1_acc0)
plt.title("s1_acc0")
plt.show()

plt.plot(iter,s2_acc0)
plt.title("s2_acc0")
plt.show()

plt.plot(iter,s0_acc0)
plt.title("s0_acc1")
plt.show()

plt.plot(iter,s1_acc0)
plt.title("s1_acc1")
plt.show()

plt.plot(iter,s2_acc0)
plt.title("s2_acc1")
plt.show()

#val

plt.plot(epoch, AP50)
plt.title("VAL AP50")
plt.show()

plt.plot(epoch,mAP)
plt.title("mAP")
plt.show()

# %%
#{"mode": "train", "epoch": 1, "iter": 1050, "lr": 5e-05, "memory": 8994, "data_time": 0.00407, "loss_rpn_cls0_w0.5": 0.00742, "loss_rpn_bbox0_w0.5": 0.0035, "loss_rpn_cls1": 0.01133, "loss_rpn_bbox1": 0.00609, "s0.loss_cls0_w0.5": 0.08677, "s0.acc0": 47.03711, "s0.loss_bbox0_w0.5": 0.07776, "s1.loss_cls0_w0.5": 0.0236, "s1.acc0": 48.54883, "s1.loss_bbox0_w0.5": 0.01544, "s2.loss_cls0_w0.5": 0.0048, "s2.acc0": 49.41016, "s2.loss_bbox0_w0.5": 0.00222, "s0.loss_cls1": 0.16868, "s0.acc1": 94.04297, "s0.loss_bbox1": 0.14835, "s1.loss_cls1": 0.0447, "s1.acc1": 97.23828, "s1.loss_bbox1": 0.02953, "s2.loss_cls1": 0.00893, "s2.acc1": 98.86328, "s2.loss_bbox1": 0.00439, "loss": 0.64351, "time": 0.72019}
#{"mode": "val", "epoch": 1, "iter": 106, "lr": 5e-05, "AP50": 0.913, "mAP": 0.91305}
i=1
it=0
iter=[]
lr=[]
loss=[]
AP50=[]
mAP=[]
s0_acc0=[]
s1_acc0=[]
s2_acc0=[]
s0_acc1=[]
s1_acc1=[]
s2_acc1=[]
epoch=[]
with open("work_dirs/new_epoch7_fine/20220531_133700.log.json", "r+", encoding="utf8") as f:
    for item in jsonlines.Reader(f):
        if "mode" in item.keys():
            if item['mode'] == 'train':
                lr.append(item['lr'])
                loss.append(item['loss'])
                s0_acc0.append(item['s0.acc0'])
                s1_acc0.append(item['s1.acc0'])
                s2_acc0.append(item['s2.acc0'])
                s0_acc1.append(item['s0.acc1'])
                s1_acc1.append(item['s1.acc1'])
                s2_acc1.append(item['s2.acc1'])
                iter.append(it)
                it+=50
            
            if item['mode'] == 'val':
                if "AP50" in item.keys():
                    AP50.append(item['AP50'])
                    mAP.append(item['mAP'])
                    epoch.append(i)
                    i+=1

#train
plt.plot(iter, lr)
plt.title("learing rate")
plt.show()

plt.plot(iter,s0_acc0)
plt.title("s0_acc0")
plt.show()

plt.plot(iter,s1_acc0)
plt.title("s1_acc0")
plt.show()

plt.plot(iter,s0_acc0)
plt.title("s2_acc0")
plt.show()

plt.plot(iter,s1_acc0)
plt.title("s0_acc1")
plt.show()

plt.plot(iter,s0_acc0)
plt.title("s1_acc1")
plt.show()

plt.plot(iter,s1_acc0)
plt.title("s2_acc1")
plt.show()


#val

plt.plot(epoch, AP50)
plt.title("VAL AP50")
plt.show()

plt.plot(epoch,mAP)
plt.title("mAP")
plt.show()
